# %% [markdown]
# ## Transformer / Classification

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv("C:/data/DSA_features.csv")

# %%
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.columns
# Out:
# Index(['T_xacc_mean', 'T_xacc_max', 'T_xacc_min', 'T_xacc_var', 'T_xacc_std',
#        'T_xacc_skew', 'T_yacc_mean', 'T_yacc_max', 'T_yacc_min', 'T_yacc_var',
#        ...
#        'LL_ymag_std', 'LL_ymag_skew', 'LL_zmag_mean', 'LL_zmag_max',
#        'LL_zmag_min', 'LL_zmag_var', 'LL_zmag_std', 'LL_zmag_skew', 'activity',
#        'people'],
#       dtype='object', length=272)

# %%
df['activity'].value_counts()
# Out:
# activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64

# %%
print("2. 두개 (lying+jumping) activity를 섞어서 test")
# Out:
# 2. 두개 (lying+jumping) activity를 섞어서 test

# %%
df_F = df[df['activity'].isin(['sitting', 'jumping'])]
df_F = df_F.drop('people', axis=1)
df_F.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729   sitting
# 1  7.032302e-07     0.000839      0.347471   sitting
# 2  6.268222e-07     0.000792      0.045579   sitting
# 3  8.011245e-07     0.000895      0.240690   sitting
# 4  6.853423e-07     0.000828      0.258429   sitting
#
# [5 rows x 271 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

df_F['activity'] = label_encoder.fit_transform(df_F['activity'])

df_F.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729         1
# 1  7.032302e-07     0.000839      0.347471         1
# 2  6.268222e-07     0.000792      0.045579         1
# 3  8.011245e-07     0.000895      0.240690         1
# 4  6.853423e-07     0.000828      0.258429         1
#
# [5 rows x 271 columns]

# %%
df_F['activity'].value_counts()
# Out:
# activity
# 1    480
# 0    480
# Name: count, dtype: int64

# %%
print("DSA데이터에서 lyingRigh 480 lyingBack 480을 정상 (normal) jumping(abnormal)을 비정상 데이터로 사용")
# Out:
# DSA데이터에서 lyingRigh 480 lyingBack 480을 정상 (normal) jumping(abnormal)을 비정상 데이터로 사용

# %%
LABELS = ["Normal", "Abnormal"]

# %%
normal = df_F[df_F.activity == 1]
abnormal = df_F[df_F.activity == 0]

# %%
normal.shape
# Out:
# (480, 271)

# %%
abnormal.shape
# Out:
# (480, 271)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df_F, test_size=0.25, random_state=21)

X_train.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 8533     9.696725     57.7120    -15.4390  273.983844   16.552457
# 8498     7.384707     45.8470     -5.1440   76.995035    8.774681
# 432      7.837118      7.9158      7.7477    0.000946    0.030757
# 23       7.845960      8.0704      7.7122    0.006734    0.082062
# 97       9.625296      9.7031      9.5397    0.000730    0.027010
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 8533     1.128046    -0.763323   13.232000   -12.34900   15.023461  ...
# 8498     1.537783    -1.821385    2.924300   -18.70000   11.383479  ...
# 432      0.140361    -0.138929    0.004876    -0.25011    0.003084  ...
# 23       0.311689     1.317432    1.418200     1.21120    0.001361  ...
# 97       0.041497    -1.066845   -0.911650    -1.21650    0.004851  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 8533  7.479717e-03     0.086485      0.007972     -0.355485    -0.254960
# 8498  1.002358e-02     0.100118      0.845274     -0.209810     0.000000
# 432   1.110522e-04     0.010538     -0.026247      0.373648     0.406920
# 23    8.698413e-07     0.000933      0.407586     -0.056491    -0.054181
# 97    5.779270e-07     0.000760      0.154149      0.639557     0.641310
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 8533    -0.412670  1.321084e-03     0.036347      0.590537         0
# 8498    -0.330950  1.178642e-02     0.108565      1.275136         0
# 432      0.342890  1.054404e-04     0.010268      0.296544         1
# 23      -0.058535  7.164530e-07     0.000846      0.208636         1
# 97       0.637330  6.460357e-07     0.000804     -0.184050         1
#
# [5 rows x 271 columns]

# %%
X_train, X_valid = train_test_split(X_train, test_size=0.25, random_state=21)

X_valid.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 8618     8.970245     35.8320     -5.3968  121.820029   11.037211
# 266      6.973882      7.0413      6.8771    0.001130    0.033622
# 8446     9.241331     47.5600     -9.7867  239.189761   15.465761
# 8271     9.706705     38.5200    -10.1460   61.239750    7.825583
# 144      8.892325      8.9736      8.7550    0.001106    0.033262
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 8618     0.584564    -2.473182      1.1685    -7.76760    6.836901  ...
# 266     -0.374500    -0.415361     -0.3418    -0.49029    0.000595  ...
# 8446     0.992539    -0.865305      1.0280    -6.81550    2.271754  ...
# 8271     0.679210    -0.188361      2.8969    -4.43130    1.062270  ...
# 144     -0.272485    -1.654110     -1.5085    -1.73850    0.001262  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 8618  6.161438e-04     0.024822      0.065349      0.624493      0.68403
# 266   5.567413e-07     0.000746     -0.281143      0.288966      0.29092
# 8446  2.519201e-03     0.050192     -0.078233      0.295131      0.32893
# 8271  2.045038e-03     0.045222      0.473233      0.467954      0.55604
# 144   1.296282e-05     0.003600     -0.520068      0.491878      0.49406
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 8618      0.57282  9.574787e-04     0.030943      0.272426         0
# 266       0.28700  6.445057e-07     0.000803      0.005432         1
# 8446      0.26300  2.039860e-04     0.014282      0.087653         0
# 8271      0.34723  1.722934e-03     0.041508     -0.459704         0
# 144       0.48952  1.036685e-06     0.001018      0.016231         1
#
# [5 rows x 271 columns]

# %%
X_train = X_train[X_train.activity == 1]
X_valid = X_valid[X_valid.activity == 1]

y_train = X_train['activity']
y_valid = X_valid['activity']

X_train = X_train.drop(['activity'], axis=1)
X_valid = X_valid.drop(['activity'], axis=1)

# %%
X_train
# Out:
#      T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 431     7.773832      7.8581      7.7131    0.001112    0.033351     0.338038
# 355     7.975595      8.1248      7.8561    0.003421    0.058492     0.448509
# 442     7.708062      7.7645      7.6627    0.000392    0.019799     0.203253
# 268     6.967674      7.0411      6.8843    0.000778    0.027894    -0.435737
# 419     9.090847      9.2026      8.9869    0.001467    0.038298     0.251490
# ..           ...         ...         ...         ...         ...          ...
# 417     9.093501      9.1954      9.0013    0.001490    0.038603     0.022129
# 3       7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 303     8.177614      8.3759      8.0332    0.005027    0.070901     0.422641
# 421     7.521659      7.5689      7.4556    0.000579    0.024069    -0.467314
# 370     9.302749      9.4528      9.1767    0.002150    0.046364     0.295267
#
#      T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_min  \
# 431    -0.137570   -0.068253    -0.25646    0.000989  ...     0.249580
# 355    -0.266635   -0.192980    -0.32718    0.000780  ...     0.654320
# 442    -0.276837   -0.188490    -0.34497    0.001251  ...     0.303720
# 268    -0.417147   -0.371410    -0.49734    0.000515  ...     0.714500
# 419    -2.061086   -1.985500    -2.16350    0.001164  ...     0.425450
# ..           ...         ...         ...         ...  ...          ...
# 417    -2.031048   -1.904700    -2.11940    0.001321  ...     0.426380
# 3       1.165260    1.317000     1.07870    0.002173  ...     0.300880
# 303    -0.476188   -0.389490    -0.56869    0.001296  ...     0.685790
# 421    -0.650900   -0.539460    -0.72413    0.000863  ...     0.037199
# 370    -1.840361   -1.743600    -1.95260    0.001446  ...     0.450760
#
#       LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 431  1.381329e-04     0.011753     -0.018944      0.391791     0.422460
# 355  4.160690e-07     0.000645     -0.075341      0.301284     0.303190
# 442  5.984913e-05     0.007736      0.396378      0.368229     0.403210
# 268  4.204708e-07     0.000648      0.141325      0.289135     0.291050
# 419  5.169787e-07     0.000719     -0.329619      0.712772     0.714340
# ..            ...          ...           ...           ...          ...
# 417  5.449339e-07     0.000738      0.201130      0.712732     0.714540
# 3    5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 303  5.339831e-07     0.000731     -0.150117      0.075571     0.077661
# 421  9.591852e-05     0.009794     -0.036504      0.465779     0.492610
# 370  4.152251e-07     0.000644     -0.171868      0.703648     0.705290
#
#      LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 431     0.356010  2.761632e-04     0.016618     -0.426711
# 355     0.299500  5.029771e-07     0.000709      0.057268
# 442     0.339260  7.807912e-05     0.008836      0.567575
# 268     0.287160  5.971381e-07     0.000773     -0.016001
# 419     0.711360  4.636514e-07     0.000681      0.078890
# ..           ...           ...          ...           ...
# 417     0.711110  4.650123e-07     0.000682      0.104129
# 3      -0.058310  8.011245e-07     0.000895      0.240690
# 303     0.073375  5.248618e-07     0.000724     -0.108742
# 421     0.442870  8.470957e-05     0.009204      0.178072
# 370     0.702320  4.945205e-07     0.000703      0.149043
#
# [268 rows x 270 columns]

# %%
y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

# %%
X_test
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 44       7.821673      8.1005      7.6150    0.008474    0.092057
# 16       7.941903      8.1156      7.8093    0.005502    0.074176
# 8444     9.421165     41.4480    -10.6520  231.008568   15.198966
# 218      9.189202      9.2863      9.1075    0.001118    0.033435
# 180      9.172114      9.2888      9.0952    0.001016    0.031871
# ...           ...         ...         ...         ...         ...
# 8233     9.679842     28.7940     -8.9027   43.224416    6.574528
# 61       9.649295     10.1710      8.6383    0.028846    0.169843
# 166      9.029174      9.0934      8.9882    0.000442    0.021034
# 8535     9.089712     58.0250    -12.3670  258.586906   16.080638
# 123      8.969338      9.0053      8.9153    0.000344    0.018554
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 44       0.102453     1.464138     1.53480      1.4015    0.000783  ...
# 16      -0.103582     1.243725     1.31550      1.0933    0.001341  ...
# 8444     0.957402    -0.876496     1.24420     -4.5647    1.760685  ...
# 218      0.049977    -1.559160    -1.51440     -1.6256    0.000407  ...
# 180      0.613950    -1.538318    -1.41970     -1.6405    0.000679  ...
# ...           ...          ...         ...         ...         ...  ...
# 8233     0.412524    -0.094610     2.93620     -2.6024    0.699882  ...
# 61      -2.021061    -0.527739     0.13225     -1.0973    0.067309  ...
# 166      0.257276    -1.499974    -1.43730     -1.5857    0.001095  ...
# 8535     1.158603    -0.167065    19.73800     -9.1724   16.273141  ...
# 123     -0.362862    -1.569039    -1.50530     -1.6832    0.001222  ...
#
#       LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 44        0.30120  7.720624e-07     0.000879     -0.243314     -0.057050
# 16        0.29959  6.908694e-07     0.000831      0.096034     -0.056704
# 8444      0.16818  2.523371e-03     0.050233      0.089071      0.279730
# 218       0.43645  4.762399e-07     0.000690      0.378089      0.567469
# 180       0.43788  1.162096e-06     0.001078     -0.102081      0.568588
# ...           ...           ...          ...           ...           ...
# 8233     -0.42638  1.330597e-03     0.036477      0.726154      0.449924
# 61        0.53474  6.048461e-06     0.002459     -0.321234      0.645984
# 166       0.62322  2.915472e-05     0.005400     -0.148292      0.485639
# 8535     -0.18122  5.665147e-03     0.075267     -0.397062     -0.350758
# 123       0.61928  5.830467e-07     0.000764     -0.112126      0.498323
#
#       LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 44      -0.055184    -0.059168  6.077006e-07     0.000780     -0.240921
# 16      -0.054438    -0.058375  5.717767e-07     0.000756     -0.035031
# 8444     0.309850     0.234190  2.435095e-04     0.015605     -0.197136
# 218      0.569210     0.565630  4.393903e-07     0.000663     -0.198255
# 180      0.570270     0.565980  5.886184e-07     0.000767      0.055005
# ...           ...          ...           ...          ...           ...
# 8233     0.526350     0.348010  1.534100e-03     0.039168     -0.768903
# 61       0.648640     0.641030  2.354196e-06     0.001534     -0.884666
# 166      0.489300     0.481800  3.791472e-06     0.001947     -0.071940
# 8535    -0.236410    -0.419220  1.432308e-03     0.037846      0.718173
# 123      0.499850     0.496700  4.008450e-07     0.000633     -0.035188
#
# [240 rows x 270 columns]

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.layers import Input, Dense

input_dim = X_train.shape[1]
encoding_dim = 7

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
history = autoencoder.fit(X_train, X_train, 
                          epochs=20, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 5.5722 - val_loss: 5.5251
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 5.5682 - val_loss: 5.5216
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 5.5646 - val_loss: 5.5187
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 5.5613 - val_loss: 5.5161
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.5584 - val_loss: 5.5139
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 5.5560 - val_loss: 5.5119
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 5.5539 - val_loss: 5.5098
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 5.5520 - val_loss: 5.5075
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 5.5500 - val_loss: 5.5050
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.5478 - val_loss: 5.5022
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.5455 - val_loss: 5.4993
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 5.5430 - val_loss: 5.4959
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 5.5402 - val_loss: 5.4923
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.5371 - val_loss: 5.4882
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 5.5336 - val_loss: 5.4838
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 5.5296 - val_loss: 5.4788
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.5252 - val_loss: 5.4735
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.5203 - val_loss: 5.4677
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.5150 - val_loss: 5.4615
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.5093 - val_loss: 5.4548

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#        reconstruction_error  true_class
# count            240.000000  240.000000
# mean             226.939563    0.504167
# std              347.078181    0.501028
# min                5.317192    0.000000
# 25%                5.433674    0.000000
# 50%               11.185580    1.000000
# 75%              388.576593    1.000000
# max             2489.861976    1.000000

# %%
error_df.head()
# Out:
#       reconstruction_error  true_class
# 44                5.397847           1
# 16                5.422940           1
# 8444            882.871940           0
# 218               5.423895           1
# 180               5.435522           1

# %%
threshold = 20

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     119.0
#            1       0.00      0.00      0.00     121.0
#
#     accuracy                           0.00     240.0
#    macro avg       0.00      0.00      0.00     240.0
# weighted avg       0.00      0.00      0.00     240.0

# %% [markdown]
# ## Load The DataSet

# %%
import numpy as np
import keras
from keras import layers

# %%
def readucr(filename): 
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)
#x는 input data, y는 정수형 레이블로 반환

# %%
root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

# %%
x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
n_classes = len(np.unique(y_train))

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
n_samples = 100  
n_timesteps = 10  
n_features = 5 
x_train = np.random.rand(n_samples, n_timesteps, n_features).astype(np.float32)
y_train = np.random.randint(0, 2, size=(n_samples, 1)).astype(np.float32)  

n_test_samples = 20  
x_test = np.random.rand(n_test_samples, n_timesteps, n_features).astype(np.float32)
y_test = np.random.randint(0, 2, size=(n_test_samples, 1)).astype(np.float32)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon = 1e-6)(x)
    res = x + inputs

# %% [markdown]
# ## Build the model

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
   
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x + inputs)  
    x_ff = layers.Dense(ff_dim, activation="relu")(x)
    x_ff = layers.Dropout(dropout)(x_ff)
    x = layers.Dense(inputs.shape[-1])(x_ff)  
    x = layers.LayerNormalization(epsilon=1e-6)(x + inputs)  
    return x

# %%
def build_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0, mlp_dropout=0):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    
    outputs = layers.Dense(1, activation="sigmoid")(x)  
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Train and evaluate

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

# 모델 컴파일
model.compile(
    loss="binary_crossentropy",  # 이중 분류에 맞는 손실 함수
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["accuracy"],
)

model.summary()

# 모델 훈련
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=20,  # 에포크 수를 줄였습니다.
    batch_size=32,  # 배치 크기를 32로 설정했습니다.
    callbacks=callbacks,
)

# 모델 평가
model.evaluate(x_test, y_test, verbose=1)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 10, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 5)     │     23,557 │ input_layer_1[0]… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 10, 5)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 10, 5)     │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 10, 5)     │         10 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 10, 4)     │         24 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 10, 4)     │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 10, 5)     │         25 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 10, 5)     │          0 │ dense_5[0][0],    │
# │                     │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 5)     │     23,557 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 10, 5)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 10, 5)     │          0 │ dropout_4[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 10, 4)     │         24 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 10, 4)     │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 10, 5)     │         25 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 10, 5)     │          0 │ dense_7[0][0],    │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 5)     │     23,557 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 10, 5)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 10, 5)     │          0 │ dropout_7[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10, 4)     │         24 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 10, 4)     │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 10, 5)     │         25 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 10, 5)     │          0 │ dense_9[0][0],    │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 5)     │     23,557 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 10, 5)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 10, 5)     │          0 │ dropout_10[0][0], │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 10, 4)     │         24 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10, 4)     │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10, 5)     │         25 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 10, 5)     │          0 │ dense_11[0][0],   │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 5)         │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │        768 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 128)       │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1)         │        129 │ dropout_12[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 95,401 (372.66 KB)
#  Trainable params: 95,401 (372.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 528ms/step - accuracy: 0.5594 - loss: 0.6782 - val_accuracy: 0.5000 - val_loss: 0.6991
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4695 - loss: 0.6950 - val_accuracy: 0.5500 - val_loss: 0.6971
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4961 - loss: 0.7049 - val_accuracy: 0.5000 - val_loss: 0.6958
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4984 - loss: 0.7017 - val_accuracy: 0.5000 - val_loss: 0.6938
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5297 - loss: 0.6912 - val_accuracy: 0.5000 - val_loss: 0.6924
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5664 - loss: 0.6913 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5922 - loss: 0.6797 - val_accuracy: 0.5000 - val_loss: 0.6906
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4031 - loss: 0.7019 - val_accuracy: 0.5000 - val_loss: 0.6895
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4750 - loss: 0.7014 - val_accuracy: 0.5000 - val_loss: 0.6888
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5109 - loss: 0.6883 - val_accuracy: 0.5000 - val_loss: 0.6886
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3664 - loss: 0.7135 - val_accuracy: 0.5000 - val_loss: 0.6885
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4797 - loss: 0.6836 - val_accuracy: 0.5000 - val_loss: 0.6884
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4500 - loss: 0.7034 - val_accuracy: 0.5000 - val_loss: 0.6880
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5703 - loss: 0.6867 - val_accuracy: 0.5000 - val_loss: 0.6877
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5031 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6870
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3891 - loss: 0.7112 - val_accuracy: 0.5500 - val_loss: 0.6863
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5938 - loss: 0.6852 - val_accuracy: 0.5500 - val_loss: 0.6857
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4336 - loss: 0.7017 - val_accuracy: 0.6000 - val_loss: 0.6851
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4859 - loss: 0.7038 - val_accuracy: 0.6000 - val_loss: 0.6845
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4570 - loss: 0.6943 - val_accuracy: 0.6000 - val_loss: 0.6838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3500 - loss: 0.7114
# [0.7113963961601257, 0.3499999940395355]
