# %% [markdown]
# <a href="https://colab.research.google.com/github/kilgwijong/DeepLearning_2024_2/blob/main/1%EC%A3%BC%EC%B0%A8_%EB%A6%AC%ED%8F%AC%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
file = files.upload()
# Out:
#      <input type="file" id="files-1d8930b6-306e-4f5d-90d3-2d0b7a674b93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d8930b6-306e-4f5d-90d3-2d0b7a674b93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
import io
import pandas as pd
from google.colab import files

# Upload the file
file = files.upload()

# Get the first filename from the uploaded files
# (assuming only one file is uploaded at a time)
filename = list(file.keys())[0]

# Access the file contents using the actual filename
file_content = file[filename]

df = pd.read_csv(io.BytesIO(file_content))
# Out:
#      <input type="file" id="files-230063de-9d78-47e6-a5f2-b4f8bffb26ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-230063de-9d78-47e6-a5f2-b4f8bffb26ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x=df.drop('Outcome', axis=1)
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **SCV**

# %%
f
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, Y_train)

pred_svm = clf_svm.predict(X_test)
print("\n- SVM -")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-38d498a7c978> in <cell line: 5>()
#       3
#       4 clf_svm = SVC(random_state=0)
# ----> 5 clf_svm.fit(X_train, Y_train)
#       6
#       7 pred_svm = clf_svm.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# **LR**

# %%
clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, Y_train)
pred_lr=clf_lr.predict(X_test)
print ("\n -LR-")
print(accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))
# Out:
#  -LR-
# 0.7916666666666666
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-06507442a47a> in <cell line: 6>()
#       4 print ("\n -LR-")
#       5 print(accuracy_score(y_test, pred_lr))
# ----> 6 print(confusion_matrix(y_test, pred_lr))
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# **KNN**

# %%
from sklearn.neural_network import MLPClassifier
clf_nn = MLPClassifier (random_state=0)
clf_nn.fit(X_train, Y_train)
pred_nn = clf_nn.predict(X_test)
print ("\n -NN-")
print (accuracy_score(y_test, pred_nn))
print (confusion_matrix(y_test, pred_nn))
# Out:
#  -NN-
# 0.7239583333333334
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-53e83917c102> in <cell line: 7>()
#       5 print ("\n -NN-")
#       6 print (accuracy_score(y_test, pred_nn))
# ----> 7 print (confusion_matrix(y_test, pred_nn))
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# **DT**

# %%
from sklearn.tree import DecisionTreeClassifier
clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, Y_train)
pred_dt = clf_dt.predict(X_test)
print ("\n -DT-")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
#  -DT-
# 0.71875
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-51dc824425fc> in <cell line: 7>()
#       5 print ("\n -DT-")
#       6 print (accuracy_score(y_test, pred_dt))
# ----> 7 print (confusion_matrix(y_test, pred_dt))
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# **RF**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
print ("\n- RF -")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, Y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# - RF -
# 0.7708333333333334
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-cb0afba6f1ba> in <cell line: 11>()
#       9 pred = rf_clf.predict(X_test)
#      10 print(accuracy_score(y_test,pred))
# ---> 11 print (confusion_matrix(y_test, pred))
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# ---

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=50, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5850 - loss: 1.7719 - val_accuracy: 0.6510 - val_loss: 0.7209
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6561 - loss: 0.7229 - val_accuracy: 0.6562 - val_loss: 0.6447
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6504 - loss: 0.6728 - val_accuracy: 0.5833 - val_loss: 0.8928
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6482 - loss: 0.6875 - val_accuracy: 0.6354 - val_loss: 0.7299
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6605 - loss: 0.8002 - val_accuracy: 0.6510 - val_loss: 0.6853
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7243 - loss: 0.6411 - val_accuracy: 0.6667 - val_loss: 0.7883
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6836 - loss: 0.8063 - val_accuracy: 0.6146 - val_loss: 0.8876
# Epoch 8/50
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Dense Layer Model Accuracy: {accuracy:.4f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7047 - loss: 0.6622
# Dense Layer Model Accuracy: 0.6979

# %% [markdown]
# ---

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_reg = df.drop(['Outcome', 'BMI'], axis=1)
Y_reg = df['BMI']

# %%
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, Y_reg, test_size=0.2, random_state=42)

# %%
X_train_reg_scaled = scaler.fit_transform(X_train_reg)
X_test_reg_scaled = scaler.transform(X_test_reg)

# %%
reg_models = {
    'Linear Regression': LinearRegression(),
    'Random Forest Regression': RandomForestRegressor()
}

# %%
for name, model in reg_models.items():
  model.fit(X_train_reg_scaled, y_train_reg)
  y_pred_reg = model.predict(X_test_reg_scaled)
  mse = mean_squared_error(y_test_reg, y_pred_reg)
  print(f"{name} MSE: {mse:.4f}")
# Out:
# Linear Regression MSE: 52.2406
# Random Forest Regression MSE: 49.5462

# %% [markdown]
# ---

# %%
reg_model = Sequential()
reg_model.add(Dense(128, input_dim=X_train_reg.shape[1], activation='relu'))
reg_model.add(Dense(64, activation='relu'))
reg_model.add(Dense(1))

# %%
reg_model.compile(optimizer='adam', loss='mse')

# %%
reg_model.fit(X_train_reg_scaled, y_train_reg, epochs=50, batch_size=10, validation_data=(X_test_reg_scaled, y_test_reg))
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 921.9854 - val_loss: 371.5186
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 235.6102 - val_loss: 110.4050
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 92.5289 - val_loss: 92.0363
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 72.3740 - val_loss: 87.4682
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 71.5234 - val_loss: 84.3352
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.7393 - val_loss: 85.9063
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 53.4093 - val_loss: 77.8414
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 55.1092 - val_loss: 81.2569
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 46.2411 - val_loss: 77.6625
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.6488 - val_loss: 76.3001
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.9136 - val_loss: 75.0248
# ...

# %%
mse = reg_model.evaluate(X_test_reg_scaled, y_test_reg)
print(f"Dense Layer Regression Model MSE: {mse:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 63.1560
# Dense Layer Regression Model MSE: 64.7118
